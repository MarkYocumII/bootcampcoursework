# %% [markdown]
# # Coaster Speed
#
# ### Instructions
#
# <img src="../Images/CoasterSpeed.png" width=400></img>
#
# * Create a line chart with two plots using the following data...
#
#     * `Danger Drop: [9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50]`
#
#     * `RailGun: [75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30]`
#
#     * Both coasters are 120 seconds long and the speed was measured every 10 seconds.
#
# * Apply styling and labels that match the image provided.

# %% [markdown]
# #### Include this cell for interactive plots

# %%
# %matplotlib notebook

# %% [markdown]
# #### Import dependencies

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Create the X and Y axis lists using the data from the instructions
#
# - **HINT:** your x-axis is going to be the time of the rollercoaster.
# - **HINT:** your y-axis data is provided in the instructions

# %%
time = np.arange(0,130,10)
DD_speeds = [9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50]
RG_speeds = [75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30]

# %% [markdown]
# #### Plot the charts and apply some styling

# %%
danger_drop, = plt.plot(time, DD_speeds, color="red", label="Danger Drop")
railgun, = plt.plot(time, RG_speeds, color="blue", label="RailGun")
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %% [markdown]
# #### Add labels to X and Y axes and also add title

# %%
plt.title("Coaster Speed Over Time")
plt.xlabel("Coaster Runtime")
plt.ylabel("Speed (MPH)")
# Out:
# Text(0, 0.5, 'Speed (MPH)')

# %% [markdown]
# #### Set the limits for the X and Y axes

# %%
plt.xlim(0,120)
plt.ylim(5,100)
# Out:
# (5, 100)

# %% [markdown]
# #### Create a legend for the chart

# %%
plt.legend(loc="best")

# %% [markdown]
# #### Add in a grid for the chart

# %%
plt.grid()

# %% [markdown]
# #### Display your plot

# %%
plt.savefig("../Images/CoasterSpeed.png")
plt.show()
