# %% [markdown]
# # Scatter Plot
#
#
# ### [Scatter plot documentation](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html)

# %% [markdown]
# #### Run this cell for interactive plots

# %%
# %matplotlib notebook

# %% [markdown]
# #### Import Dependencies
#
# [Documentation for `random` module](https://docs.python.org/2/library/random.html)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Create data

# %%
# The maximum x value for our chart will be 100
x_limit = 100

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = np.arange(0, x_limit, 1)

# Create a random array of data that we will use for our y values
data = [random.random() for value in x_axis]

# %% [markdown]
# #### Create a scatter plot
# - The size of each point on our plot is determined by their x value
#
#
# ##### Arguments:
# - **x** -> data for x-axis
# - **y** -> data for y-axis
# - **marker**-> shape to use for datapoints
# - **facecolors** -> color of the center of each datapoint
# - **edgecolors** -> color of the edge of each datapoint
# - **s** -> data to determine the size of each datapoint
# - **alpha** -> transparenct of the datapoints (0 = completely transparent)

# %%
plt.scatter(x=x_axis, y=data, marker="o", facecolors="orange", edgecolors="blue", s=x_axis, alpha=0.8)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# #### The y limits of our scatter plot is 0 to 1

# %%
plt.ylim(0, 1)
# Out:
# (0, 1)

# %% [markdown]
# #### The x limits of our scatter plot is 0 to 100

# %%
plt.xlim(0, x_limit)
# Out:
# (0, 100)

# %% [markdown]
# #### Prints the scatter plot to the screen

# %%
plt.show()
